# %%
import pandas as pd 
import numpy as np

# %%
gender =['male','female']

# %%
age = ['less then 18','18 - 24 years old','25 - 49 years old','50 - 64 years old','65+']

# %%
country = ['Belgium', 'Bulgaria', 'Czechia', 'Denmark', 'Germany', 'Estonia', 'Ireland', 'Greece', 'Spain', 
        'France', 'Croatia', 'Italy','Cyprus','Latvia','Lithuania','Luxembourg','Hungary','Malta','Netherlands','Austria',
        'Poland','Portugal','Romania','Slovenia','Slovakia','Finland','Sweden','United Kingdom','Iceland','Norway',
        'Switzerland','Montenegro','North Macedonia','Serbia','Turkey']

# %%
sector = ['Agriculture, Forestry, Fishing & Hunting', 'Mining, Quarrying, & Oil & Gas Extraction',
          'Utilities','Construction','Manufacturing','Wholesale','Retail','Transportation & Warehousing',
          'Information','Finance & Insurance','Real Estate & Rental & Leasing','Professional, Scientific & Technical Services',
          'Management of Companies & Enterprises', 'Administrative, Support & Waste & Remediation','Educational Services',
          'Health Care & Social Assistance','Arts, Entertainment & Recreation','Accommodation & Food Services','Others Services']

# %%
education = ['high school',' undergraduate','masters','phD', 'MBA', 'other']

# %%
management = ["don't manage a team",'manage a team between 1 to 5 people','manage a team between 6 to 10 people',
              'manage more then 10 people']

# %%
perception = []

# %%
income = []
#1 to 1.000.000+

# %%
  
index = range(1,30000)
columns = ['gender','age','country','sector','education','management','income', 'perception']

df = pd.DataFrame(index=index, columns=columns)

# %%
df['gender'] = np.random.choice(list(gender), len(df))
df['age'] = np.random.choice(list(age), len(df))
df['country'] = np.random.choice(list(country), len(df))
df['sector'] = np.random.choice(list(sector), len(df))
df['education'] = np.random.choice(list(education), len(df))
df['management'] = np.random.choice(list(management), len(df))
df
# Out:
#        gender                age      country  \
# 1        male       less then 18  Netherlands
# 2        male  50 - 64 years old      Hungary
# 3        male       less then 18       Turkey
# 4      female  18 - 24 years old      Hungary
# 5      female       less then 18       Norway
# ...       ...                ...          ...
# 29995  female  50 - 64 years old      Croatia
# 29996  female  50 - 64 years old      Estonia
# 29997  female       less then 18        Italy
# 29998  female                65+      Finland
# 29999    male  18 - 24 years old      Finland
#
#                                           sector       education  \
# 1                Health Care & Social Assistance     high school
# 2                  Accommodation & Food Services             MBA
# 3                           Educational Services             phD
# 4               Arts, Entertainment & Recreation   undergraduate
# 5                   Transportation & Warehousing             MBA
# ...                                          ...             ...
# 29995                                  Wholesale           other
# 29996               Transportation & Warehousing             phD
# 29997                       Educational Services           other
# 29998  Mining, Quarrying, & Oil & Gas Extraction             phD
# 29999                                  Utilities         masters
#
#                                  management income perception
# 1      manage a team between 6 to 10 people    NaN        NaN
# 2       manage a team between 1 to 5 people    NaN        NaN
# 3                       don't manage a team    NaN        NaN
# 4                manage more then 10 people    NaN        NaN
# 5       manage a team between 1 to 5 people    NaN        NaN
# ...                                     ...    ...        ...
# 29995  manage a team between 6 to 10 people    NaN        NaN
# 29996            manage more then 10 people    NaN        NaN
# 29997            manage more then 10 people    NaN        NaN
# 29998  manage a team between 6 to 10 people    NaN        NaN
# 29999   manage a team between 1 to 5 people    NaN        NaN
#
# [29999 rows x 8 columns]

# %%
df.groupby(["country", "gender",'age']).count()
# Out:
#                                          sector  education  management  \
# country        gender age
# Austria        female 18 - 24 years old      96         96          96
#                       25 - 49 years old      80         80          80
#                       50 - 64 years old      87         87          87
#                       65+                    83         83          83
#                       less then 18           72         72          72
# ...                                         ...        ...         ...
# United Kingdom male   18 - 24 years old      85         85          85
#                       25 - 49 years old      60         60          60
#                       50 - 64 years old      76         76          76
#                       65+                    81         81          81
#                       less then 18           75         75          75
#
#                                          income  perception
# country        gender age
# Austria        female 18 - 24 years old       0           0
#                       25 - 49 years old       0           0
#                       50 - 64 years old       0           0
#                       65+                     0           0
#                       less then 18            0           0
# ...                                         ...         ...
# United Kingdom male   18 - 24 years old       0           0
#                       25 - 49 years old       0           0
#                       50 - 64 years old       0           0
#                       65+                     0           0
#                       less then 18            0           0
#
# [350 rows x 5 columns]
